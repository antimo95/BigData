# %% [markdown]
# #Caricamento Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/videogames.csv')
df
# Out:
#       index  Rank                        Game Title Platform    Year  \
# 0         0     1                        Wii Sports      Wii  2006.0
# 1         1     2                 Super Mario Bros.      NES  1985.0
# 2         2     3                    Mario Kart Wii      Wii  2008.0
# 3         3     4                 Wii Sports Resort      Wii  2009.0
# 4         4     5                            Tetris       GB  1989.0
# ...     ...   ...                               ...      ...     ...
# 1902   1902  1903  Lizzie McGuire 2: Lizzie Diaries      GBA  2004.0
# 1903   1903  1904              Xenoblade Chronicles      Wii  2010.0
# 1904   1904  1905                     SingStar Abba      PS3  2008.0
# 1905   1905  1906    FIFA Soccer World Championship      PS2  2000.0
# 1906   1906  1907        WWE SmackDown vs. Raw 2011     X360  2010.0
#
#              Genre                    Publisher  North America  Europe  Japan  \
# 0           Sports                     Nintendo          40.43   28.39   3.77
# 1         Platform                     Nintendo          29.08    3.58   6.81
# 2           Racing                     Nintendo          14.50   12.22   3.63
# 3           Sports                     Nintendo          14.82   10.51   3.18
# 4           Puzzle                     Nintendo          23.20    2.26   4.22
# ...            ...                          ...            ...     ...    ...
# 1902        Action   Disney Interactive Studios           0.60    0.22   0.00
# 1903  Role-Playing                     Nintendo           0.39    0.22   0.16
# 1904          Misc  Sony Computer Entertainment           0.25    0.44   0.00
# 1905        Sports              Electronic Arts           0.27    0.21   0.28
# 1906      Fighting                          THQ           0.42    0.32   0.00
#
#       Rest of World  Global  Review
# 0              8.54   81.12   76.28
# 1              0.77   40.24   91.00
# 2              3.21   33.55   82.07
# 3              3.01   31.52   82.65
# 4              0.58   30.26   88.00
# ...             ...     ...     ...
# 1902           0.01    0.83   55.00
# 1903           0.07    0.83   91.74
# 1904           0.14    0.83   73.00
# 1905           0.07    0.83   73.00
# 1906           0.09    0.83   82.00
#
# [1907 rows x 13 columns]

# %% [markdown]
# #Rimozione righe con valori nulli

# %%
# Rimuovi le righe con valori nulli
df_cleaned = df.dropna()
# Mostra le prime righe del DataFrame pulito
df_cleaned
# Out:
#       index  Rank                        Game Title Platform    Year  \
# 0         0     1                        Wii Sports      Wii  2006.0
# 1         1     2                 Super Mario Bros.      NES  1985.0
# 2         2     3                    Mario Kart Wii      Wii  2008.0
# 3         3     4                 Wii Sports Resort      Wii  2009.0
# 4         4     5                            Tetris       GB  1989.0
# ...     ...   ...                               ...      ...     ...
# 1902   1902  1903  Lizzie McGuire 2: Lizzie Diaries      GBA  2004.0
# 1903   1903  1904              Xenoblade Chronicles      Wii  2010.0
# 1904   1904  1905                     SingStar Abba      PS3  2008.0
# 1905   1905  1906    FIFA Soccer World Championship      PS2  2000.0
# 1906   1906  1907        WWE SmackDown vs. Raw 2011     X360  2010.0
#
#              Genre                    Publisher  North America  Europe  Japan  \
# 0           Sports                     Nintendo          40.43   28.39   3.77
# 1         Platform                     Nintendo          29.08    3.58   6.81
# 2           Racing                     Nintendo          14.50   12.22   3.63
# 3           Sports                     Nintendo          14.82   10.51   3.18
# 4           Puzzle                     Nintendo          23.20    2.26   4.22
# ...            ...                          ...            ...     ...    ...
# 1902        Action   Disney Interactive Studios           0.60    0.22   0.00
# 1903  Role-Playing                     Nintendo           0.39    0.22   0.16
# 1904          Misc  Sony Computer Entertainment           0.25    0.44   0.00
# 1905        Sports              Electronic Arts           0.27    0.21   0.28
# 1906      Fighting                          THQ           0.42    0.32   0.00
#
#       Rest of World  Global  Review
# 0              8.54   81.12   76.28
# 1              0.77   40.24   91.00
# 2              3.21   33.55   82.07
# 3              3.01   31.52   82.65
# 4              0.58   30.26   88.00
# ...             ...     ...     ...
# 1902           0.01    0.83   55.00
# 1903           0.07    0.83   91.74
# 1904           0.14    0.83   73.00
# 1905           0.07    0.83   73.00
# 1906           0.09    0.83   82.00
#
# [1878 rows x 13 columns]

# %% [markdown]
# #Collegamento a MongoDB Atlas

# %%
# !pip install -U pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 19.0 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 20.5 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
def get_mongo_client(mongo_uri):
  """Establish connection to the MongoDB."""
  try:
    client = pymongo.MongoClient(mongo_uri)
    print("Connection to MongoDB successful")
    return client
  except pymongo.errors.ConnectionFailure as e:
    print(f"Connection failed: {e}")
    return None

# %%
import pandas as pd
import pymongo
from pymongo import MongoClient



mongo_uri = "mongodb+srv://antimo:esame123@bigdata.nuu2w.mongodb.net/?retryWrites=true&w=majority&appName=BigData"

mongo_client = get_mongo_client(mongo_uri)

# Ingest data into MongoDB
db = mongo_client['HW3']
collection = db['Games']

# Delete any existing records in the collection
collection.delete_many({})

#Inserimento del dataframe in mongoDB come dizionario
documents = df_cleaned.to_dict('records')
collection.insert_many(documents)
# Out:
# Connection to MongoDB successful
# InsertManyResult([ObjectId('67570c783acf65f0f43dec71'), ObjectId('67570c783acf65f0f43dec72'), ObjectId('67570c783acf65f0f43dec73'), ObjectId('67570c783acf65f0f43dec74'), ObjectId('67570c783acf65f0f43dec75'), ObjectId('67570c783acf65f0f43dec76'), ObjectId('67570c783acf65f0f43dec77'), ObjectId('67570c783acf65f0f43dec78'), ObjectId('67570c783acf65f0f43dec79'), ObjectId('67570c783acf65f0f43dec7a'), ObjectId('67570c783acf65f0f43dec7b'), ObjectId('67570c783acf65f0f43dec7c'), ObjectId('67570c783acf65f0f43dec7d'), ObjectId('67570c783acf65f0f43dec7e'), ObjectId('67570c783acf65f0f43dec7f'), ObjectId('67570c783acf65f0f43dec80'), ObjectId('67570c783acf65f0f43dec81'), ObjectId('67570c783acf65f0f43dec82'), ObjectId('67570c783acf65f0f43dec83'), ObjectId('67570c783acf65f0f43dec84'), ObjectId('67570c783acf65f0f43dec85'), ObjectId('67570c783acf65f0f43dec86'), ObjectId('67570c783acf65f0f43dec87'), ObjectId('67570c783acf65f0f43dec88'), ObjectId('67570c783acf65f0f43dec89'), ObjectId('67570c783acf65f0f43dec8a'), ObjectId('67570c783acf65f0f43dec8b'), ObjectId('67570c783acf65f0f43dec8c'), ObjectId('67570c783acf65f0f43dec8d'), ObjectId('67570c783acf65f0f43dec8e'), ObjectId('67570c783acf65f0f43dec8f'), ObjectId('67570c783acf65f0f43dec90'), ObjectId('67570c783acf65f0f43dec91'), ObjectId('67570c783acf65f0f43dec92'), ObjectId('67570c783acf65f0f43dec93'), ObjectId('67570c783acf65f0f43dec94'), ObjectId('67570c783acf65f0f43dec95'), ObjectId('67570c783acf65f0f43dec96'), ObjectId('67570c783acf65f0f43dec97'), ObjectId('67570c783acf65f0f43dec98'), ObjectId('67570c783acf65f0f43dec99'), ObjectId('67570c783acf65f0f43dec9a'), ObjectId('67570c783acf65f0f43dec9b'), ObjectId('67570c783acf65f0f43dec9c'), ObjectId('67570c783acf65f0f43dec9d'), ObjectId('67570c783acf65f0f43dec9e'), ObjectId('67570c783acf65f0f43dec9f'), ObjectId('67570c783acf65f0f43deca0'), ObjectId('67570c783acf65f0f43deca1'), ObjectId('67570c783acf65f0f43deca2'), ObjectId('67570c783acf65f0f43deca3'), ObjectId('67570c783acf65f0f43deca4'), ObjectId('67570c783acf65f0f43deca5'), ObjectId('67570c783acf65f0f43deca6'), ObjectId('67570c783acf65f0f43deca7'), ObjectId('67570c783acf65f0f43deca8'), ObjectId('67570c783acf65f0f43deca9'), ObjectId('67570c783acf65f0f43decaa'), ObjectId('67570c783acf65f0f43decab'), ObjectId('67570c783acf65f0f43decac'), ObjectId('67570c783acf65f0f43decad'), ObjectId('67570c783acf65f0f43decae'), ObjectId('67570c783acf65f0f43decaf'), ObjectId('67570c783acf65f0f43decb0'), ObjectId('67570c783acf65f0f43decb1'), ObjectId('67570c783acf65f0f43decb2'), ObjectId('67570c783acf65f0f43decb3'), ObjectId('67570c783acf65f0f43decb4'), ObjectId('67570c783acf65f0f43decb5'), ObjectId('67570c783acf65f0f43decb6'), ObjectId('67570c783acf65f0f43decb7'), ObjectId('67570c783acf65f0f43decb8'), ObjectId('67570c783acf65f0f43decb9'), ObjectId('67570c783acf65f0f43decba'), ObjectId('67570c783acf65f0f43decbb'), ObjectId('67570c783acf65f0f43decbc'), ObjectId('67570c783acf65f0f43decbd'), ObjectId('67570c783acf65f0f43decbe'), ObjectId('67570c783acf65f0f43decbf'), ObjectId('67570c783acf65f0f43decc0'), ObjectId('67570c783acf65f0f43decc1'), ObjectId('67570c783acf65f0f43decc2'), ObjectId('67570c783acf65f0f43decc3'), ObjectId('67570c783acf65f0f43decc4'), ObjectId('67570c783acf65f0f43decc5'), ObjectId('67570c783acf65f0f43decc6'), ObjectId('67570c783acf65f0f43decc7'), ObjectId('67570c783acf65f0f43decc8'), ObjectId('67570c783acf65f0f43decc9'), ObjectId('67570c783acf65f0f43decca'), ObjectId('67570c783acf65f0f43deccb'), ObjectId('67570c783acf65f0f43deccc'), ObjectId('67570c783acf65f0f43deccd'), ObjectId('67570c783acf65f0f43decce'), ObjectId('67570c783acf65f0f43deccf'), ObjectId('67570c783acf65f0f43decd0'), ObjectId('67570c783acf65f0f43decd1'), ObjectId('67570c783acf65f0f43decd2'), ObjectId('67570c783acf65f0f43decd3'), ObjectId('67570c783acf65f0f43decd4'), ObjectId('67570c783acf65f0f43decd5'), ObjectId('67570c783acf65f0f43decd6'), ObjectId('67570c783acf65f0f43decd7'), ObjectId('67570c783acf65f0f43decd8'), ObjectId('67570c783acf65f0f43d ...

# %%
# Esegui una query per ottenere tutti i documenti dalla collezione
cursor = collection.find({})

# Converti i risultati della query in una lista di dizionari
data_list = list(cursor)

# Chiudi il cursore
cursor.close()

# Converti la lista di dizionari in un DataFrame
df = pd.DataFrame(data_list)

#Stampa dataset
df
# Out:
#                            _id  index  Rank                        Game Title  \
# 0     67570c783acf65f0f43dec71      0     1                        Wii Sports
# 1     67570c783acf65f0f43dec72      1     2                 Super Mario Bros.
# 2     67570c783acf65f0f43dec73      2     3                    Mario Kart Wii
# 3     67570c783acf65f0f43dec74      3     4                 Wii Sports Resort
# 4     67570c783acf65f0f43dec75      4     5                            Tetris
# ...                        ...    ...   ...                               ...
# 1873  67570c783acf65f0f43df3c2   1902  1903  Lizzie McGuire 2: Lizzie Diaries
# 1874  67570c783acf65f0f43df3c3   1903  1904              Xenoblade Chronicles
# 1875  67570c783acf65f0f43df3c4   1904  1905                     SingStar Abba
# 1876  67570c783acf65f0f43df3c5   1905  1906    FIFA Soccer World Championship
# 1877  67570c783acf65f0f43df3c6   1906  1907        WWE SmackDown vs. Raw 2011
#
#      Platform    Year         Genre                    Publisher  \
# 0         Wii  2006.0        Sports                     Nintendo
# 1         NES  1985.0      Platform                     Nintendo
# 2         Wii  2008.0        Racing                     Nintendo
# 3         Wii  2009.0        Sports                     Nintendo
# 4          GB  1989.0        Puzzle                     Nintendo
# ...       ...     ...           ...                          ...
# 1873      GBA  2004.0        Action   Disney Interactive Studios
# 1874      Wii  2010.0  Role-Playing                     Nintendo
# 1875      PS3  2008.0          Misc  Sony Computer Entertainment
# 1876      PS2  2000.0        Sports              Electronic Arts
# 1877     X360  2010.0      Fighting                          THQ
#
#       North America  Europe  Japan  Rest of World  Global  Review
# 0             40.43   28.39   3.77           8.54   81.12   76.28
# 1             29.08    3.58   6.81           0.77   40.24   91.00
# 2             14.50   12.22   3.63           3.21   33.55   82.07
# 3             14.82   10.51   3.18           3.01   31.52   82.65
# 4             23.20    2.26   4.22           0.58   30.26   88.00
# ...             ...     ...    ...            ...     ...     ...
# 1873           0.60    0.22   0.00           0.01    0.83   55.00
# 1874           0.39    0.22   0.16           0.07    0.83   91.74
# 1875           0.25    0.44   0.00           0.14    0.83   73.00
# 1876           0.27    0.21   0.28           0.07    0.83   73.00
# 1877           0.42    0.32   0.00           0.09    0.83   82.00
#
# [1878 rows x 14 columns]

# %% [markdown]
# #QUERY

# %%
pipeline = [
    {"$group": {"_id": "$Game Title", "game_count": {"$sum": 1}}},
    {"$sort": {"game_count": -1}}
]

result = collection.aggregate(pipeline)

# Converti i risultati in un DataFrame pandaas
df = pd.DataFrame(list(result))
# Rinomina il campo _id
df = df.rename(columns={'_id': 'game_name'})
# Stampa il DataFrame in formato tabellare
df.head(10)
# Out:
#                                      game_name  game_count
# 0                               FIFA Soccer 08           6
# 1                    Pro Evolution Soccer 2008           5
# 2                            The Simpsons Game           5
# 3  LEGO Indiana Jones: The Original Adventures           5
# 4                    WWE SmackDown vs Raw 2008           5
# 5               Star Wars: The Force Unleashed           5
# 6                               FIFA Soccer 10           5
# 7                    Need for Speed: ProStreet           4
# 8                                   The Sims 3           4
# 9               LEGO Star Wars: The Video Game           4

# %%
pipeline = [
    {"$group": {"_id": "$Genre", "Media_Globale": {"$avg": "$Global"}}},
    {"$sort": {"Media_Globale": -1}}
]

result = collection.aggregate(pipeline)

# Converti i risultati in un DataFrame pandaas
df = pd.DataFrame(list(result))

# Rinomina il campo _id
df = df.rename(columns={'_id': 'Genre'})

# Stampa il DataFrame in formato tabellare
df.head(10)
# Out:
#           Genre  Media_Globale
# 0      Platform       3.189677
# 1  Role-Playing       2.889123
# 2          Misc       2.726471
# 3       Shooter       2.713627
# 4        Puzzle       2.469318
# 5        Racing       2.438804
# 6        Action       2.331360
# 7        Sports       2.281221
# 8    Simulation       2.229783
# 9     Adventure       2.191524

# %%
pipeline = [
    {
        "$match": {
            "Genre": {"$in": ["Platform", "Role-Playing", "Misc"]}
        }
    },
    {
        "$group": {
            "_id": {"Publisher": "$Publisher", "Genre": "$Genre"},
            "game_count": {"$sum": 1}
        }
    },
    {
        "$sort": {
            "game_count": -1
        }
    }
]
result = collection.aggregate(pipeline)

for i in result:
  print(i)
# Out:
# {'_id': {'Publisher': 'Nintendo', 'Genre': 'Platform'}, 'game_count': 67}
# {'_id': {'Publisher': 'Nintendo', 'Genre': 'Role-Playing'}, 'game_count': 38}
# {'_id': {'Publisher': 'Nintendo', 'Genre': 'Misc'}, 'game_count': 32}
# {'_id': {'Publisher': 'Sega', 'Genre': 'Platform'}, 'game_count': 30}
# {'_id': {'Publisher': 'Sony Computer Entertainment', 'Genre': 'Misc'}, 'game_count': 27}
# {'_id': {'Publisher': 'Activision', 'Genre': 'Misc'}, 'game_count': 23}
# {'_id': {'Publisher': 'Square Enix', 'Genre': 'Role-Playing'}, 'game_count': 23}
# {'_id': {'Publisher': 'Sony Computer Entertainment', 'Genre': 'Platform'}, 'game_count': 21}
# {'_id': {'Publisher': 'Square', 'Genre': 'Role-Playing'}, 'game_count': 16}
# {'_id': {'Publisher': 'THQ', 'Genre': 'Platform'}, 'game_count': 16}
# {'_id': {'Publisher': 'Activision', 'Genre': 'Role-Playing'}, 'game_count': 15}
# {'_id': {'Publisher': 'Sony Computer Entertainment', 'Genre': 'Role-Playing'}, 'game_count': 13}
# {'_id': {'Publisher': 'Ubisoft', 'Genre': 'Misc'}, 'game_count': 13}
# {'_id': {'Publisher': 'Activision', 'Genre': 'Platform'}, 'game_count': 10}
# {'_id': {'Publisher': 'Capcom', 'Genre': 'Platform'}, 'game_count': 10}
# {'_id': {'Publisher': 'Electronic Arts', 'Genre': 'Role-Playing'}, 'game_count': 9}
# {'_id': {'Publisher': 'Bethesda Softworks', 'Genre': 'Role-Playing'}, 'game_count': 9}
# {'_id': {'Publisher': 'Enix Corporation', 'Genre': 'Role-Playing'}, 'game_count': 8}
# {'_id': {'Publisher': 'Sega', 'Genre': 'Misc'}, 'game_count': 8}
# {'_id': {'Publisher': 'Disney Interactive Studios', 'Genre': 'Misc'}, 'game_count': 8}
# {'_id': {'Publisher': 'Capcom', 'Genre': 'Role-Playing'}, 'game_count': 7}
# {'_id': {'Publisher': 'Namco Bandai Games', 'Genre': 'Role-Playing'}, 'game_count': 7}
# {'_id': {'Publisher': 'Microsoft Game Studios', 'Genre': 'Role-Playing'}, 'game_count': 6}
# {'_id': {'Publisher': 'MTV Games', 'Genre': 'Misc'}, 'game_count': 6}
# {'_id': {'Publisher': 'Electronic Arts', 'Genre': 'Platform'}, 'game_count': 6}
# {'_id': {'Publisher': 'Namco Bandai Games', 'Genre': 'Misc'}, 'game_count': 5}
# {'_id': {'Publisher': 'Konami Digital Entertainment', 'Genre': 'Platform'}, 'game_count': 5}
# {'_id': {'Publisher': 'Electronic Arts', 'Genre': 'Misc'}, 'game_count': 4}
# {'_id': {'Publisher': 'Microsoft Game Studios', 'Genre': 'Misc'}, 'game_count': 4}
# {'_id': {'Publisher': 'Konami Digital Entertainment', 'Genre': 'Role-Playing'}, 'game_count': 4}
# {'_id': {'Publisher': 'Universal Interactive', 'Genre': 'Platform'}, 'game_count': 3}
# {'_id': {'Publisher': 'RedOctane', 'Genre': 'Misc'}, 'game_count': 3}
# {'_id': {'Publisher': 'Hasbro Interactive', 'Genre': 'Misc'}, 'game_count': 3}
# {'_id': {'Publisher': 'Ubisoft', 'Genre': 'Platform'}, 'game_count': 3}
# {'_id': {'Publisher': 'Sega', 'Genre': 'Role-Playing'}, 'game_count': 3}
# {'_id': {'Publisher': 'Virgin Interactive', 'Genre': 'Platform'}, 'game_count': 3}
# {'_id': {'Publisher': 'Konami Digital Entertainment', 'Genre': 'Misc'}, 'game_count': 2}
# {'_id': {'Publisher': 'Disney Interactive Studios', 'Genre': 'Platform'}, 'game_count': 2}
# {'_id': {'Publisher': 'Hudson Soft', 'Genre': 'Platform'}, 'game_count': 2}
# {'_id': {'Publisher': 'Atari', 'Genre': 'Role-Playing'}, 'game_count': 2}
# {'_id': {'Publisher': 'Level 5', 'Genre': 'Role-Playing'}, 'game_count': 2}
# {'_id': {'Publisher': 'Ubisoft', 'Genre': 'Role-Playing'}, 'game_count': 2}
# {'_id': {'Publisher': 'Midway Games', 'Genre': 'Misc'}, 'game_count': 2}
# {'_id': {'Publisher': 'THQ', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'Infogrames', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'NCSoft', 'Genre': 'Role-Playing'}, 'game_count': 1}
# {'_id': {'Publisher': 'Acclaim Entertainment', 'Genre': 'Platform'}, 'game_count': 1}
# {'_id': {'Publisher': 'GT Interactive', 'Genre': 'Platform'}, 'game_count': 1}
# {'_id': {'Publisher': 'Rising Star Games', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'GT Interactive', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'Play It', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'Take-Two Interactive', 'Genre': 'Role-Playing'}, 'game_count': 1}
# {'_id': {'Publisher': 'Crave Entertainment', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'Pacific Century Cyber Works', 'Genre': 'Role-Playing'}, 'game_count': 1}
# {'_id': {'Publisher': 'Sammy Corporation', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'Take-Two Interactive', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'Majesco Entertainment', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'GSP', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'Atari', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'Take-Two Interactive', 'Genre': 'Platform'}, 'game_count': 1}
# {'_id': {'Publisher': 'Crave Entertainment', 'Genre': 'Role-Playing'}, 'game_count': 1}
# {'_id': {'Publisher': 'GameBank', 'Genre': 'Platform'}, 'game_count': 1}
# {'_id': {'Publisher': 'Crystal Dynamics', 'Genre': 'Platform'}, 'game_count': 1}
# {'_id': {'Publisher': 'TDK Mediactive', 'Genre': 'Platform'}, 'game_count': 1}
# {'_id': {'Publisher': 'Mindscape', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'Vivendi Games', 'Genre': 'Platform'}, 'game_count': 1}
# {'_id': {'Publisher': 'Pinnacle', 'Genre': 'Misc'}, 'game_count': 1}
# {'_id': {'Publisher': 'Sony Online Entertainment', 'Genre': 'Role-Playing'}, 'game_count': 1}
# {'_id': {'Publisher': 'Havas Interactive', 'Genre': 'Role-Playing'}, 'game_count': 1}
# {'_id': {'Publisher': 'Infogrames', 'Genre': 'Role-Playing'}, 'game_count': 1}
# {'_id': {'Publisher': 'Hasbro Interactive', 'Genre': 'Platform'}, 'game_count': 1}

# %%
pipeline = [
    {
        "$match": {
            "Publisher": "Nintendo",
            "Genre": "Platform"
        }
    },
    {
        "$group": {
            "_id": "$Publisher",
            "Vendite_Medie_Gobali": {"$avg": "$Global"}
        }
    }
]

result = collection.aggregate(pipeline)

# Converti i risultati in un DataFrame pandas
df = pd.DataFrame(list(result))

# Rinomina il campo _id
df = df.rename(columns={'_id': 'Publisher'})

# Mostra il DataFrame in formato tabellare
print(df)
# Out:
#   Publisher  Vendite_Medie_Gobali
# 0  Nintendo              5.740597

# %%
pipeline = [
    {
        "$match": {
            "Publisher": "Nintendo"
        }
    },
    {
        "$group": {
            "_id": "$Year",
            "AVG_Annuale": {"$avg": "$Global"}
        }
    },
    {
        "$sort": {
            "AVG_Annuale": -1
        }
    }
]

result = collection.aggregate(pipeline)

# Converti i risultati in un DataFrame pandas
df = pd.DataFrame(list(result))

# Rinomina il campo _id
df = df.rename(columns={'_id': 'Year'})

# Mostra il DataFrame in formato tabellare
print(df)
# Out:
#       Year  AVG_Annuale
# 0   2006.0    11.232353
# 1   1989.0     9.833333
# 2   1985.0     9.704000
# 3   2009.0     8.651429
# 4   1988.0     6.860000
# 5   2005.0     6.820588
# 6   1984.0     6.184286
# 7   2008.0     6.159231
# 8   1999.0     5.602727
# 9   2007.0     5.600000
# 10  1990.0     5.070000
# 11  1994.0     4.578000
# 12  1993.0     4.322500
# 13  1992.0     4.228889
# 14  1996.0     4.212222
# 15  2002.0     4.063636
# 16  2010.0     4.009231
# 17  1997.0     3.721667
# 18  1995.0     3.707500
# 19  1998.0     3.548462
# 20  2001.0     3.200000
# 21  2011.0     3.081000
# 22  1987.0     2.987500
# 23  1986.0     2.935000
# 24  2012.0     2.891429
# 25  2004.0     2.568421
# 26  2000.0     2.262143
# 27  2003.0     2.178000
# 28  1991.0     2.017143
# 29  1983.0     1.826667

# %%
# Esegui l'aggregazione con ordinamento
pipeline = [
    {
        "$match": {
            "Review": {"$gt": 8},
            "Global": {"$gt": 20}
        }
    },
    #Voglio visualizzare solo alcuni attributi
    {
        "$project": {
            "Game Title": 1,
            "Review": 1,
            "Global": 1,
            "_id" : 0 #Escludo l'id per avere un risultato più pulito
        }
    },
    {
        "$sort": {
            "Global": -1  # Ordina in base a "Global" in ordine decrescente
        }
    }
]

result = collection.aggregate(pipeline)

# Converti i risultati in un DataFrame pandas
df = pd.DataFrame(list(result))

# Mostra il DataFrame in formato tabellare
df.head(10)
# Out:
#                   Game Title  Global  Review
# 0                 Wii Sports   81.12   76.28
# 1          Super Mario Bros.   40.24   91.00
# 2             Mario Kart Wii   33.55   82.07
# 3          Wii Sports Resort   31.52   82.65
# 4                     Tetris   30.26   88.00
# 5      New Super Mario Bros.   29.08   90.00
# 6                   Wii Play   28.71   61.64
# 7                  Duck Hunt   28.31   84.00
# 8  New Super Mario Bros. Wii   26.75   88.18
# 9                 Nintendogs   24.50   85.00

# %%
# Esegui l'aggregazione con ordinamento
pipeline = [
    {
        "$match": {
            "Review": {"$gt": 8},
            "Global": {"$gt": 20}
        }
    },
    #Voglio visualizzare solo alcuni attributi
    {
        "$project": {
            "Game Title": 1,
            "Review": 1,
            "Global": 1,
            "Year" : 1, #Aggiungo Year
            "_id" : 0 #Escludo l'id per avere un risultato più pulito
        }
    },
    {
        "$sort": {
            "Global": -1  # Ordina in base a "Global" in ordine decrescente
        }
    }
]

result = collection.aggregate(pipeline)

# Converti i risultati in un DataFrame pandas
df = pd.DataFrame(list(result))

# Mostra il DataFrame in formato tabellare
df.head(10)
# Out:
#                   Game Title    Year  Global  Review
# 0                 Wii Sports  2006.0   81.12   76.28
# 1          Super Mario Bros.  1985.0   40.24   91.00
# 2             Mario Kart Wii  2008.0   33.55   82.07
# 3          Wii Sports Resort  2009.0   31.52   82.65
# 4                     Tetris  1989.0   30.26   88.00
# 5      New Super Mario Bros.  2006.0   29.08   90.00
# 6                   Wii Play  2006.0   28.71   61.64
# 7                  Duck Hunt  1984.0   28.31   84.00
# 8  New Super Mario Bros. Wii  2009.0   26.75   88.18
# 9                 Nintendogs  2005.0   24.50   85.00

# %%
pipeline = [
    {
        "$match": {
            "Publisher": "Nintendo",
            "Year": 2006
        }
    },
    {
        "$project": {
            "Game Title": 1,
            "Global": 1,
            "_id": 0  # Escludi il campo _id
        }
    },
    {
        "$sort": {
            "Global": -1  # Ordina in base a "Global" in ordine decrescente
        }
    }
]

result = collection.aggregate(pipeline)

# Converti i risultati in un DataFrame pandas
df = pd.DataFrame(list(result))

# Mostra il DataFrame in formato tabellare
print(df)
# Out:
#                                            Game Title  Global
# 0                                          Wii Sports   81.12
# 1                               New Super Mario Bros.   29.08
# 2                                            Wii Play   28.71
# 3                     Pokémon Diamond / Pearl Version   18.05
# 4              The Legend of Zelda: Twilight Princess    6.76
# 5                                     Clubhouse Games    3.35
# 6   English Training: Have Fun Improving Your Skills!    3.33
# 7                           Personal Trainer: Cooking    3.09
# 8                             WarioWare: Smooth Moves    2.84
# 9                                   Yoshi's Island DS    2.69
# 10                                     Pokémon Ranger    2.11
# 11                                          Tetris DS    2.07
# 12                                 Kirby Squeak Squad    1.91
# 13             The Legend of Zelda: Twilight Princess    1.59
# 14                                 Mario Hoops 3 on 3    1.57
# 15                          Pokémon Battle Revolution    1.52
# 16        Mario vs. Donkey Kong 2: March of the Minis    1.16

# %%
pipeline = [
    {
        "$group": {
            "_id": {"Platform": "$Platform", "Year": "$Year"},
            "game_count": {"$sum": 1}
        }
    },
    {
        "$sort": {
            "game_count": -1
        }
    }
]

result = collection.aggregate(pipeline)

counter = 0

for i in result:
    if counter < 20:
        print(i)
        counter += 1
    else:
        break
# Out:
# {'_id': {'Platform': 'PS2', 'Year': 2002.0}, 'game_count': 66}
# {'_id': {'Platform': 'PS2', 'Year': 2004.0}, 'game_count': 64}
# {'_id': {'Platform': 'PS2', 'Year': 2003.0}, 'game_count': 59}
# {'_id': {'Platform': 'PS', 'Year': 1998.0}, 'game_count': 55}
# {'_id': {'Platform': 'PS2', 'Year': 2005.0}, 'game_count': 48}
# {'_id': {'Platform': 'PS', 'Year': 1999.0}, 'game_count': 45}
# {'_id': {'Platform': 'X360', 'Year': 2010.0}, 'game_count': 43}
# {'_id': {'Platform': 'PS2', 'Year': 2001.0}, 'game_count': 43}
# {'_id': {'Platform': 'PS3', 'Year': 2008.0}, 'game_count': 43}
# {'_id': {'Platform': 'X360', 'Year': 2008.0}, 'game_count': 42}
# {'_id': {'Platform': 'Wii', 'Year': 2008.0}, 'game_count': 40}
# {'_id': {'Platform': 'PS', 'Year': 1997.0}, 'game_count': 38}
# {'_id': {'Platform': 'PS3', 'Year': 2010.0}, 'game_count': 37}
# {'_id': {'Platform': 'DS', 'Year': 2007.0}, 'game_count': 37}
# {'_id': {'Platform': 'Wii', 'Year': 2007.0}, 'game_count': 36}
# {'_id': {'Platform': 'X360', 'Year': 2011.0}, 'game_count': 36}
# {'_id': {'Platform': 'DS', 'Year': 2008.0}, 'game_count': 35}
# {'_id': {'Platform': 'PS3', 'Year': 2011.0}, 'game_count': 34}
# {'_id': {'Platform': 'PS3', 'Year': 2009.0}, 'game_count': 33}
# {'_id': {'Platform': 'Wii', 'Year': 2009.0}, 'game_count': 33}

# %%
pipeline = [
    {
        "$group": {
            "_id": "$Publisher",
            "Vendite_NA": {"$sum": "$North America"},
            "Vendite_EU": {"$sum": "$Europe"},
            "Vendite_JP": {"$sum": "$Japan"},
            "Vendite_RW": {"$sum": "$Rest of World"},
            "Vendite_Globali": {"$sum": "$Global"}
        }
    },
    {
        "$sort": {
            "Vendite_Globali": -1
        }
    }
]

result = collection.aggregate(pipeline)

# Converti i risultati in un DataFrame pandas
df = pd.DataFrame(list(result))

# Rinomina il campo _id
df = df.rename(columns={'_id': 'Publisher'})

# Mostra il DataFrame in formato tabellare
df.head(10)
# Out:
#                      Publisher  Vendite_NA  Vendite_EU  Vendite_JP  \
# 0                     Nintendo      687.79      341.49      338.04
# 1              Electronic Arts      345.25      203.04        8.72
# 2  Sony Computer Entertainment      167.59      119.19       50.27
# 3                   Activision      218.68      112.82        3.66
# 4         Take-Two Interactive      112.64       67.43        3.82
# 5                      Ubisoft      103.23       69.61        1.79
# 6       Microsoft Game Studios      110.68       43.22        2.37
# 7                          THQ       80.19       47.00        2.58
# 8                         Sega       60.53       39.73       11.26
# 9                       Capcom       49.42       24.31       32.91
#
#    Vendite_RW  Vendite_Globali
# 0       80.54          1447.81
# 1       67.23           624.18
# 2       40.51           377.61
# 3       34.85           369.98
# 4       24.50           208.42
# 5       21.69           196.32
# 6       13.37           169.73
# 7       13.27           142.98
# 8       10.27           121.80
# 9        7.76           114.33
